# %%
import pandas as pd

# %%
df = pd.read_csv('TelcoCustomerChurn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.shape
# Out:
# (7032, 21)

# %%
churn_proportions = df['Churn'].value_counts(normalize=True)
churn_proportions
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
contract_churn = df.groupby(['Contract', 'Churn']).size().unstack()
contract_churn['Churn_Rate'] = contract_churn['Yes'] / (contract_churn['No'] + contract_churn['Yes'])
display(contract_churn)
# Out:
# Churn             No   Yes  Churn_Rate
# Contract
# Month-to-month  2220  1655    0.427097
# One year        1307   166    0.112695
# Two year        1647    48    0.028319

# %%
combined_contract_metrics = average_monthly_charges_contract_churn.copy()
combined_contract_metrics['Churn_Rate'] = contract_churn['Churn_Rate']
display(combined_contract_metrics)
# Out:
# Churn                  No        Yes  Churn_Rate
# Contract
# Month-to-month  61.462635  73.019396    0.427097
# One year        62.540926  85.050904    0.112695
# Two year        60.112798  86.777083    0.028319

# %%
churn_yes_df = df[df['Churn'] == 'Yes']
display(churn_yes_df.head())
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 2             No             DSL            Yes  ...               No
# 4             No     Fiber optic             No  ...               No
# 5            Yes     Fiber optic             No  ...              Yes
# 8            Yes     Fiber optic             No  ...              Yes
# 13           Yes     Fiber optic             No  ...              Yes
#
# ...

# %%
print('Counts of features for churned customers:')
for column in churn_yes_df.columns:
    if column not in ['customerID', 'Churn']:
        print(f'\n--- {column} ---')
        display(churn_yes_df[column].value_counts())
# Out:
# Counts of features for churned customers:
#
# --- gender ---
# gender
# Female    939
# Male      930
# Name: count, dtype: int64
# --- SeniorCitizen ---
# SeniorCitizen
# 0    1393
# 1     476
# Name: count, dtype: int64
# --- Partner ---
# Partner
# No     1200
# Yes     669
# Name: count, dtype: int64
# --- Dependents ---
# Dependents
# No     1543
# Yes     326
# Name: count, dtype: int64
# --- tenure ---
# tenure
# 1     380
# 2     123
# 3      94
# 4      83
# 5      64
#      ...
# 45      6
# 71      6
# 62      5
# 63      4
# 64      4
# Name: count, Length: 72, dtype: int64
# --- PhoneService ---
# PhoneService
# Yes    1699
# No      170
# Name: count, dtype: int64
# --- MultipleLines ---
# MultipleLines
# Yes                 850
# No                  849
# No phone service    170
# Name: count, dtype: int64
# --- InternetService ---
# InternetService
# Fiber optic    1297
# DSL             459
# No              113
# Name: count, dtype: int64
# --- OnlineSecurity ---
# ...

# %%
total_charges_all_customers = df['TotalCharges'].sum()
print(f"Total Charges for all customers: {total_charges_all_customers}")
# Out:
# Total Charges for all customers: 16056168.700000001

# %%
total_charges_churned_customers = df[df['Churn'] == 'Yes']['TotalCharges'].sum()
print(f"Total Charges for churned customers: {total_charges_churned_customers}")
# Out:
# Total Charges for churned customers: 2862926.9

# %%
total_charges_non_churned_customers = df[df['Churn'] == 'No']['TotalCharges'].sum()
print(f"Total Charges for non-churned customers: {total_charges_non_churned_customers}")
# Out:
# Total Charges for non-churned customers: 13193241.8

# %%
print(f"\n--- Summary of Total Charges ---")
print(f"Total Charges for all customers: {total_charges_all_customers:,.2f}")
print(f"Total Charges for churned customers: {total_charges_churned_customers:,.2f} ({proportion_churned_total_charges:.2%})")
print(f"Total Charges for non-churned customers: {total_charges_non_churned_customers:,.2f} ({proportion_non_churned_total_charges:.2%})")
# Out:
# --- Summary of Total Charges ---
# Total Charges for all customers: 16,056,168.70
# Total Charges for churned customers: 2,862,926.90 (17.83%)
# Total Charges for non-churned customers: 13,193,241.80 (82.17%)
